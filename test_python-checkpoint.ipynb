# %%
import numpy as np
import tensorflow as tf
import helper as hp
import network_training
from importlib import reload
import multiprocessing
hp = reload(hp)
network_training = reload(network_training)


network_training.M_MIMO_DNN_CE_hyper_RNN_downlink(1,64,5,2,1,2,2,100,10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-2ffa1048acf4> in <module>()
#       1 import numpy as np
# ----> 2 import tensorflow as tf
#       3 import helper as hp
#       4 import network_training
#       5 from importlib import reload
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\__init__.py in <module>()
#      22
#      23 # pylint: disable=wildcard-import
# ---> 24 from tensorflow.python import *
#      25 # pylint: enable=wildcard-import
#      26
#
# ~\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\__init__.py in <module>()
#      61
#      62 # Framework
# ---> 63 from tensorflow.python.framework.framework_lib import *
#      64 from tensorflow.python.framework.versions import *
#      65 from tensorflow.python.framework import errors
#
# ...
